# %%
from manim import *
import manimpango
from random import *
# Out:
# Manim Community v0.14.0

# %%
def moyenne(a, b):
    (xa, ya, za) = a
    (xb, yb, zb) = b
    return ((xa+xb)/2, (ya+yb)/2, (za+zb)/2)

# %%
# %%manim CreateDot
# class CreateDot(Scene):
#     def construct(self):
#         n = 10000
#         h = 7.5
#         c = 2*h/3**(1/2)
#         extrema = [(-c/2, -h/2, 0), (c/2, -h/2, 0), (0, h/2, 0)]
#         pt = extrema[0]
#         coords = []
#         for i in range(n):
#             pt = moyenne(extrema[randint(0, 2)], pt)
#             coords.append(pt)
#         points = VGroup(*[Dot(c, radius=0.01) for c in coords])
#         self.play(ShowIncreasingSubsets(points, run_time=10.0))
# Out:
# [02/11/22 15:04:55] INFO     Animation 0 : Partial movie file        ]8;id=334815;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=92662;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py#514\514]8;;\
#                              written in '/home/samuel/Programmes/Not
#                              ebooks/media/videos/Notebooks/1080p60/p
#                              artial_movie_files/CreateDot/2724823860
#                              _937218104_1240453128.mp4'
#                     INFO     Combining to Movie file.                ]8;id=963814;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=952915;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py#608\608]8;;\
#                     INFO                                             ]8;id=740763;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=615064;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py#729\729]8;;\
#                              File ready at '/home/samuel/Programmes/
#                              Notebooks/media/videos/Notebooks/1080p6
#                              0/CreateDot.mp4'
#                     INFO     Rendered CreateDot                                  ]8;id=62206;file:///usr/lib/python3.10/site-packages/manim/scene/scene.py\scene.py]8;;\:]8;id=823495;file:///usr/lib/python3.10/site-packages/manim/scene/scene.py#237\237]8;;\
#                              Played 1 animations
# <video src="media/jupyter/CreateDot@2022-02-11@15-04-55.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim CreateCircle
# class CreateCircle(Scene):
#     def construct(self):
#         circle = Circle()  # create a circle
#         circle.set_fill(PINK, opacity=0.5)  # set the color and transparency
#         self.play(Create(circle))  # show the circle on screen
# Out:
# [01/15/22 16:16:45] INFO     Animation 0 : Using cached data (hash :     ]8;id=260951;file:///usr/lib/python3.10/site-packages/manim/renderer/cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=436565;file:///usr/lib/python3.10/site-packages/manim/renderer/cairo_renderer.py#74\74]8;;\
#                              450974505_3886669728_3768686611)
#                     INFO     Combining to Movie file.                ]8;id=874270;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=673158;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py#608\608]8;;\
#                     INFO                                             ]8;id=335463;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=291223;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py#729\729]8;;\
#                              File ready at '/home/samuel/Programmes/
#                              Notebooks/media/videos/Notebooks/1080p6
#                              0/CreateCircle.mp4'
#                     INFO     Rendered CreateCircle                               ]8;id=275106;file:///usr/lib/python3.10/site-packages/manim/scene/scene.py\scene.py]8;;\:]8;id=644699;file:///usr/lib/python3.10/site-packages/manim/scene/scene.py#237\237]8;;\
#                              Played 1 animations
# <video src="media/jupyter/CreateCircle@2022-01-15@16-16-45.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim SquareToCircle
# class SquareToCircle(Scene):
#     def construct(self):
#         circle = Circle()  # create a circle
#         circle.set_fill(PINK, opacity=0.5)  # set color and transparency
#
#         square = Square()  # create a square
#         square.rotate(PI / 4)  # rotate a certain amount
#
#         self.play(Create(square))  # animate the creation of the square
#         self.play(Transform(square, circle))  # interpolate the square into the circle
#         self.play(FadeOut(square))  # fade out animation
# Out:
# [01/15/22 16:16:47] INFO     Animation 0 : Partial movie file        ]8;id=573613;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=734837;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py#514\514]8;;\
#                              written in '/home/samuel/Programmes/Not
#                              ebooks/media/videos/Notebooks/1080p60/p
#                              artial_movie_files/SquareToCircle/45097
#                              4505_727055237_1793580042.mp4'
# [01/15/22 16:16:48] INFO     Animation 1 : Partial movie file        ]8;id=31576;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=299712;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py#514\514]8;;\
#                              written in '/home/samuel/Programmes/Not
#                              ebooks/media/videos/Notebooks/1080p60/p
#                              artial_movie_files/SquareToCircle/34786
#                              186_4289114337_1793580042.mp4'
# [01/15/22 16:16:50] INFO     Animation 2 : Partial movie file        ]8;id=795383;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=256476;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py#514\514]8;;\
#                              written in '/home/samuel/Programmes/Not
#                              ebooks/media/videos/Notebooks/1080p60/p
#                              artial_movie_files/SquareToCircle/34786
#                              186_3422280404_1793580042.mp4'
#                     INFO     Combining to Movie file.                ]8;id=162555;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=879023;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py#608\608]8;;\
#                     INFO                                             ]8;id=85978;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=834681;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py#729\729]8;;\
#                              File ready at '/home/samuel/Programmes/
#                              Notebooks/media/videos/Notebooks/1080p6
#                              0/SquareToCircle.mp4'
#                     INFO     Rendered SquareToCircle                             ]8;id=180606;file:///usr/lib/python3.10/site-packages/manim/scene/scene.py\scene.py]8;;\:]8;id=722252;file:///usr/lib/python3.10/site-packages/manim/scene/scene.py#237\237]8;;\
#                              Played 3 animations
# <video src="media/jupyter/SquareToCircle@2022-01-15@16-16-50.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim SquareAndCircle
# class SquareAndCircle(Scene):
#     def construct(self):
#         circle = Circle()  # create a circle
#         circle.set_fill(PINK, opacity=0.5)  # set the color and transparency
#
#         square = Square()  # create a square
#         square.set_fill(BLUE, opacity=0.5)  # set the color and transparency
#
#         square.next_to(circle, RIGHT, buff=0.5)  # set the position
#         self.play(Create(circle), Create(square))  # show the shapes on screen
# Out:
# [01/15/22 16:16:52] INFO     Animation 0 : Partial movie file        ]8;id=366634;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=989281;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py#514\514]8;;\
#                              written in '/home/samuel/Programmes/Not
#                              ebooks/media/videos/Notebooks/1080p60/p
#                              artial_movie_files/SquareAndCircle/4509
#                              74505_3727715569_433183230.mp4'
#                     INFO     Combining to Movie file.                ]8;id=333986;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=664496;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py#608\608]8;;\
#                     INFO                                             ]8;id=382308;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=319826;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py#729\729]8;;\
#                              File ready at '/home/samuel/Programmes/
#                              Notebooks/media/videos/Notebooks/1080p6
#                              0/SquareAndCircle.mp4'
#                     INFO     Rendered SquareAndCircle                            ]8;id=725637;file:///usr/lib/python3.10/site-packages/manim/scene/scene.py\scene.py]8;;\:]8;id=760459;file:///usr/lib/python3.10/site-packages/manim/scene/scene.py#237\237]8;;\
#                              Played 1 animations
# <video src="media/jupyter/SquareAndCircle@2022-01-15@16-16-52.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim AnimatedSquareToCircle
# class AnimatedSquareToCircle(Scene):
#     def construct(self):
#         circle = Circle()  # create a circle
#         square = Square()  # create a square
#
#         self.play(Create(square))  # show the square on screen
#         self.play(square.animate.rotate(PI / 4))  # rotate the square
#         self.play(
#             ReplacementTransform(square, circle)
#         )  # transform the square into a circle
#         self.play(
#             circle.animate.set_fill(PINK, opacity=0.5)
#         )  # color the circle on screen
# Out:
# [01/15/22 16:16:54] INFO     Animation 0 : Partial movie file        ]8;id=690211;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=655795;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py#514\514]8;;\
#                              written in '/home/samuel/Programmes/Not
#                              ebooks/media/videos/Notebooks/1080p60/p
#                              artial_movie_files/AnimatedSquareToCirc
#                              le/450974505_3976349999_1793580042.mp4'
# [01/15/22 16:16:55] INFO     Animation 1 : Partial movie file        ]8;id=100150;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=656269;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py#514\514]8;;\
#                              written in '/home/samuel/Programmes/Not
#                              ebooks/media/videos/Notebooks/1080p60/p
#                              artial_movie_files/AnimatedSquareToCirc
#                              le/34786186_2676926092_1793580042.mp4'
# [01/15/22 16:16:58] INFO     Animation 2 : Partial movie file        ]8;id=775395;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=535065;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py#514\514]8;;\
#                              written in '/home/samuel/Programmes/Not
#                              ebooks/media/videos/Notebooks/1080p60/p
#                              artial_movie_files/AnimatedSquareToCirc
#                              le/34786186_406667042_1793580042.mp4'
# [01/15/22 16:16:59] INFO     Animation 3 : Partial movie file        ]8;id=701290;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=621419;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py#514\514]8;;\
#                              written in '/home/samuel/Programmes/Not
#                              ebooks/media/videos/Notebooks/1080p60/p
#                              artial_movie_files/AnimatedSquareToCirc
#                              le/34786186_1951212091_1904605041.mp4'
#                     INFO     Combining to Movie file.                ]8;id=498712;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=521732;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py#608\608]8;;\
# [01/15/22 16:17:00] INFO                                             ]8;id=244475;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=594823;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py#729\729]8;;\
#                              File ready at '/home/samuel/Programmes/
#                              Notebooks/media/videos/Notebooks/1080p6
#                              0/AnimatedSquareToCircle.mp4'
#                     INFO     Rendered AnimatedSquareToCircle                     ]8;id=788096;file:///usr/lib/python3.10/site-packages/manim/scene/scene.py\scene.py]8;;\:]8;id=179262;file:///usr/lib/python3.10/site-packages/manim/scene/scene.py#237\237]8;;\
#                              Played 4 animations
# <video src="media/jupyter/AnimatedSquareToCircle@2022-01-15@16-17-00.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim DifferentRotations
# class DifferentRotations(Scene):
#     def construct(self):
#         left_square = Square(color=BLUE, fill_opacity=0.7).shift(2 * LEFT)
#         right_square = Square(color=GREEN, fill_opacity=0.7).shift(2 * RIGHT)
#         self.play(
#             left_square.animate.rotate(PI), Rotate(right_square, angle=PI), run_time=2
#         )
#         self.wait()
# Out:
# [01/15/22 16:17:03] INFO     Animation 0 : Partial movie file        ]8;id=685314;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=979539;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py#514\514]8;;\
#                              written in '/home/samuel/Programmes/Not
#                              ebooks/media/videos/Notebooks/1080p60/p
#                              artial_movie_files/DifferentRotations/4
#                              50974505_354220969_2178747421.mp4'
# [01/15/22 16:17:05] INFO     Animation 1 : Partial movie file        ]8;id=769998;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=940111;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py#514\514]8;;\
#                              written in '/home/samuel/Programmes/Not
#                              ebooks/media/videos/Notebooks/1080p60/p
#                              artial_movie_files/DifferentRotations/3
#                              4786186_398514950_674641909.mp4'
#                     INFO     Combining to Movie file.                ]8;id=228106;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=877275;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py#608\608]8;;\
#                     INFO                                             ]8;id=557292;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=837051;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py#729\729]8;;\
#                              File ready at '/home/samuel/Programmes/
#                              Notebooks/media/videos/Notebooks/1080p6
#                              0/DifferentRotations.mp4'
#                     INFO     Rendered DifferentRotations                         ]8;id=29940;file:///usr/lib/python3.10/site-packages/manim/scene/scene.py\scene.py]8;;\:]8;id=866790;file:///usr/lib/python3.10/site-packages/manim/scene/scene.py#237\237]8;;\
#                              Played 2 animations
# <video src="media/jupyter/DifferentRotations@2022-01-15@16-17-05.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim ShowScreenResolution
# class ShowScreenResolution(Scene):
#     def construct(self):
#         pixel_height = config["pixel_height"]  #  1080 is default
#         pixel_width = config["pixel_width"]  # 1920 is default
#         frame_width = config["frame_width"]
#         frame_height = config["frame_height"]
#         self.add(Dot())
#         d1 = Line(frame_width * LEFT / 2, frame_width * RIGHT / 2).to_edge(DOWN)
#         self.add(d1)
#         self.add(Text(str(pixel_width)).next_to(d1, UP))
#         d2 = Line(frame_height * UP / 2, frame_height * DOWN / 2).to_edge(LEFT)
#         self.add(d2)
#         self.add(Text(str(pixel_height)).next_to(d2, RIGHT))
# Out:
#                     INFO                                             ]8;id=272332;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=431685;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py#729\729]8;;\
#                              File ready at '/home/samuel/Programmes/
#                              Notebooks/media/images/Notebooks/ShowSc
#                              reenResolution_ManimCE_v0.14.0.png'
#                     INFO     Rendered ShowScreenResolution                       ]8;id=650801;file:///usr/lib/python3.10/site-packages/manim/scene/scene.py\scene.py]8;;\:]8;id=218677;file:///usr/lib/python3.10/site-packages/manim/scene/scene.py#237\237]8;;\
#                              Played 0 animations

# %%
# %%manim SingleLineColor
# class SingleLineColor(Scene):
#     def construct(self):
#         text = MarkupText(f'all in red <span fgcolor="{YELLOW}">except this</span>', color=RED)
#         self.add(text)
# Out:
# [01/15/22 16:17:11] INFO                                             ]8;id=419240;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=436000;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py#729\729]8;;\
#                              File ready at '/home/samuel/Programmes/
#                              Notebooks/media/images/Notebooks/Single
#                              LineColor_ManimCE_v0.14.0.png'
#                     INFO     Rendered SingleLineColor                            ]8;id=462839;file:///usr/lib/python3.10/site-packages/manim/scene/scene.py\scene.py]8;;\:]8;id=220596;file:///usr/lib/python3.10/site-packages/manim/scene/scene.py#237\237]8;;\
#                              Played 0 animations

# %%
manimpango.list_fonts()
# Out:
# ['C059',
#  'Cantarell',
#  'Carlito',
#  'D050000L',
#  'DejaVu Math TeX Gyre',
#  'DejaVu Sans',
#  'DejaVu Sans Mono',
#  'DejaVu Serif',
#  'FreeMono',
#  'FreeSans',
#  'FreeSerif',
#  'Liberation Mono',
#  'Liberation Sans',
#  'Liberation Serif',
#  'Monospace',
#  'Nimbus Mono PS',
#  'Nimbus Roman',
#  'Nimbus Sans',
#  'Nimbus Sans Narrow',
#  'Noto Color Emoji',
#  'Noto Kufi Arabic',
#  'Noto Looped Lao',
#  'Noto Looped Lao UI',
#  'Noto Looped Thai',
#  'Noto Looped Thai UI',
#  'Noto Music',
#  'Noto Naskh Arabic',
#  'Noto Naskh Arabic UI',
#  'Noto Nastaliq Urdu',
#  'Noto Rashi Hebrew',
#  'Noto Sans',
#  'Noto Sans Adlam',
#  'Noto Sans Adlam Unjoined',
#  'Noto Sans Anatolian Hieroglyphs',
#  'Noto Sans Arabic',
#  'Noto Sans Arabic UI',
#  'Noto Sans Armenian',
#  'Noto Sans Avestan',
#  'Noto Sans Balinese',
#  'Noto Sans Bamum',
#  'Noto Sans Bassa Vah',
#  'Noto Sans Batak',
#  'Noto Sans Bengali',
#  'Noto Sans Bengali UI',
#  'Noto Sans Bhaiksuki',
#  'Noto Sans Brahmi',
#  'Noto Sans Buginese',
#  'Noto Sans Buhid',
#  'Noto Sans CJK HK',
#  'Noto Sans CJK JP',
#  'Noto Sans CJK KR',
#  'Noto Sans CJK SC',
#  'Noto Sans CJK TC',
#  'Noto Sans Canadian Aboriginal',
#  'Noto Sans Carian',
#  'Noto Sans Caucasian Albanian',
#  'Noto Sans Chakma',
#  'Noto Sans Cham',
#  'Noto Sans Cherokee',
#  'Noto Sans Coptic',
#  'Noto Sans Cuneiform',
#  'Noto Sans Cypriot',
#  'Noto Sans Deseret',
#  'Noto Sans Devanagari',
#  'Noto Sans Devanagari UI',
#  'Noto Sans Display',
#  'Noto Sans Duployan',
#  'Noto Sans Egyptian Hieroglyphs',
#  'Noto Sans Elbasan',
#  'Noto Sans Elymaic',
#  'Noto Sans Ethiopic',
#  'Noto Sans Georgian',
#  'Noto Sans Glagolitic',
#  'Noto Sans Gothic',
#  'Noto Sans Grantha',
#  'Noto Sans Gujarati',
#  'Noto Sans Gujarati UI',
#  'Noto Sans Gunjala Gondi',
#  'Noto Sans Gurmukhi',
#  'Noto Sans Gurmukhi UI',
#  'Noto Sans Hanifi Rohingya',
#  'Noto Sans Hanunoo',
#  'Noto Sans Hatran',
#  'Noto Sans Hebrew',
#  'Noto Sans Imperial Aramaic',
#  'Noto Sans Indic Siyaq Numbers',
#  'Noto Sans Inscriptional Pahlavi',
#  'Noto Sans Inscriptional Parthian',
#  'Noto Sans Javanese',
#  'Noto Sans Kaithi',
#  'Noto Sans Kannada',
#  'Noto Sans Kannada UI',
#  'Noto Sans Kayah Li',
#  'Noto Sans Kharoshthi',
#  'Noto Sans Khmer',
#  'Noto Sans Khmer UI',
#  'Noto Sans Khojki',
#  'Noto Sans Khudawadi',
#  'Noto Sans Lao',
#  'Noto Sans Lao UI',
#  'Noto Sans Lepcha',
#  'Noto Sans Limbu',
#  'Noto Sans Linear A',
#  'Noto Sans Linear B',
#  'Noto Sans Lisu',
#  'Noto Sans Lycian',
#  'Noto Sans Lydian',
#  'Noto Sans Mahajani',
#  'Noto Sans Malayalam',
#  'Noto Sans Malayalam UI',
#  'Noto Sans Mandaic',
#  'Noto Sans Manichaean',
#  'Noto Sans Marchen',
#  'Noto Sans Masaram Gondi',
#  'Noto Sans Math',
#  'Noto Sans Mayan Numerals',
#  'Noto Sans Medefaidrin',
#  'Noto Sans Meetei Mayek',
#  'Noto Sans Mende Kikakui',
#  'Noto Sans Meroitic',
#  'Noto Sans Miao',
#  'Noto Sans Modi',
#  'Noto Sans Mongolian',
#  'Noto Sans Mono',
#  'Noto Sans Mono CJK HK',
#  'Noto Sans Mono CJK JP',
#  'Noto Sans Mono CJK KR',
#  'Noto Sans Mono CJK SC',
#  'Noto Sans Mono CJK TC',
#  'Noto Sans Mro',
#  'Noto Sans Multani',
#  'Noto Sans Myanmar',
#  'Noto Sans Myanmar UI',
#  'Noto Sans NKo',
#  'Noto Sans Nabataean',
#  'Noto Sans New Tai Lue',
#  'Noto Sans Newa',
#  'Noto Sans Nushu',
#  'Noto Sans Ogham',
#  'Noto Sans Ol Chiki',
#  'Noto Sans Old Hungarian',
#  'Noto Sans Old Italic',
#  'Noto Sans Old North Arabian',
#  'Noto Sans Old Permic',
#  'Noto Sans Old Persian',
#  'Noto Sans Old Sogdian',
#  'Noto Sans Old South Arabian',
#  'Noto Sans Old Turkic',
#  'Noto Sans Oriya',
#  'Noto Sans Oriya UI',
#  'Noto Sans Osage',
#  'Noto Sans Osmanya',
#  'Noto Sans Pahawh Hmong',
#  'Noto Sans Palmyrene',
#  'Noto Sans Pau Cin Hau',
#  'Noto Sans PhagsPa',
#  'Noto Sans Phoenician',
#  'Noto Sans Psalter Pahlavi',
#  'Noto Sans Rejang',
#  'Noto Sans Runic',
#  'Noto Sans Samaritan',
#  'Noto Sans Saurashtra',
#  'Noto Sans Sharada',
#  'Noto Sans Shavian',
#  'Noto Sans Siddham',
#  'Noto Sans SignWriting',
#  'Noto Sans Sinhala',
#  'Noto Sans Sinhala UI',
#  'Noto Sans Sogdian',
#  'Noto Sans Sora Sompeng',
#  'Noto Sans Soyombo',
#  'Noto Sans Sundanese',
#  'Noto Sans Syloti Nagri',
#  'Noto Sans Symbols',
#  'Noto Sans Symbols2',
#  'Noto Sans Syriac',
#  'Noto Sans Tagalog',
#  'Noto Sans Tagbanwa',
#  'Noto Sans Tai Le',
#  'Noto Sans Tai Tham',
#  'Noto Sans Tai Viet',
#  'Noto Sans Takri',
#  'Noto Sans Tamil',
#  'Noto Sans Tamil Supplement',
#  'Noto Sans Tamil UI',
#  'Noto Sans Telugu',
#  'Noto Sans Telugu UI',
#  'Noto Sans Thaana',
#  'Noto Sans Thai',
#  'Noto Sans Thai UI',
#  'Noto Sans Tifinagh',
#  'Noto Sans Tifinagh APT',
#  'Noto Sans Tifinagh Adrar',
#  'Noto Sans Tifinagh Agraw Imazighen',
#  'Noto Sans Tifinagh Ahaggar',
#  'Noto Sans Tifinagh Air',
#  'Noto Sans Tifinagh Azawagh',
#  'Noto Sans Tifinagh Ghat',
#  'Noto Sans Tifinagh Hawad',
#  'Noto Sans Tifinagh Rhissa Ixa',
#  'Noto Sans Tifinagh SIL',
#  'Noto Sans Tifinagh Tawellemmet',
#  'Noto Sans Tirhuta',
#  'Noto Sans Ugaritic',
#  'Noto Sans Vai',
#  'Noto Sans Wancho',
#  'Noto Sans Warang Citi',
#  'Noto Sans Yi',
#  'Noto Sans Zanabazar Square',
#  'Noto Serif',
#  'Noto Serif Ahom',
#  'Noto Serif Armenian',
#  'Noto Serif Balinese',
#  'Noto Serif Bengali',
#  'Noto Serif CJK HK',
#  'Noto Serif CJK JP',
#  'Noto Serif CJK KR',
#  'Noto Serif CJK SC',
#  'Noto Serif CJK TC',
#  'Noto Serif Devanagari',
#  'Noto Serif Display',
#  'Noto Serif Dogra',
#  'Noto Serif Ethiopic',
#  'Noto Serif Georgian',
#  'Noto Serif Grantha',
#  'Noto Serif Gujarati',
#  'Noto Serif Gurmukhi',
#  'Noto Serif Hebrew',
#  'Noto Serif Hmong Nyiakeng',
#  'Noto Serif Kannada',
#  'Noto Serif Khmer',
#  'Noto Serif Khojki',
#  'Noto Serif Lao',
#  'Noto Serif Malayalam',
#  'Noto Serif Myanmar',
#  'Noto Serif Sinhala',
#  'Noto Serif Tamil',
#  'Noto Serif Tamil Slanted',
#  'Noto Serif Tangut',
#  'Noto Serif Telugu',
#  'Noto Serif Thai',
#  'Noto Serif Tibetan',
#  'Noto Serif Yezidi',
#  'Noto Traditional Nushu',
#  'P052',
#  'Sans',
#  'Serif',
#  'Source Code Pro',
#  'Source Code Variable',
#  'Standard Symbols PS',
#  'System-ui',
#  'URW Bookman',
#  'URW Gothic',
#  'Z003']

# %%
# %%manim DifferentWeight
# class DifferentWeight(Scene):
#     def construct(self):
#         g = VGroup()
#         weight_list = dict(sorted({weight: manimpango.Weight(weight).value for weight in manimpango.Weight}.items(), key=lambda x: x[1]))
#         for weight in weight_list:
#             g += Text(weight.name, weight=weight.name, font="Open Sans")
#         self.add(g.arrange(DOWN).scale(0.5))
# Out:
# [01/15/22 16:19:37] INFO                                             ]8;id=10771;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=785561;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py#729\729]8;;\
#                              File ready at '/home/samuel/Programmes/
#                              Notebooks/media/images/Notebooks/Differ
#                              entWeight_ManimCE_v0.14.0.png'
#                     INFO     Rendered DifferentWeight                            ]8;id=833269;file:///usr/lib/python3.10/site-packages/manim/scene/scene.py\scene.py]8;;\:]8;id=723265;file:///usr/lib/python3.10/site-packages/manim/scene/scene.py#237\237]8;;\
#                              Played 0 animations

# %%
# %%manim HelloLaTeX
# class HelloLaTeX(Scene):
#     def construct(self):
#         tex = Tex(r"\TeX", font_size=144)
#         self.add(tex)
# Out:
# [01/15/22 16:22:54] INFO     Writing "\TeX" to                         ]8;id=542506;file:///usr/lib/python3.10/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=238693;file:///usr/lib/python3.10/site-packages/manim/utils/tex_file_writing.py#85\85]8;;\
#                              media/Tex/289d2805e6c5ce8b.tex
#                     INFO                                             ]8;id=626181;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=56931;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py#729\729]8;;\
#                              File ready at '/home/samuel/Programmes/
#                              Notebooks/media/images/Notebooks/HelloL
#                              aTeX_ManimCE_v0.14.0.png'
#                     INFO     Rendered HelloLaTeX                                 ]8;id=45851;file:///usr/lib/python3.10/site-packages/manim/scene/scene.py\scene.py]8;;\:]8;id=816584;file:///usr/lib/python3.10/site-packages/manim/scene/scene.py#237\237]8;;\
#                              Played 0 animations

# %%
# %%manim AddPackageLatex
# class AddPackageLatex(Scene):
#     def construct(self):
#         myTemplate = TexTemplate()
#         myTemplate.add_to_preamble(r"\usepackage{mathrsfs}")
#         tex = Tex(r'$\mathscr{H} \rightarrow \mathbb{H}$}', tex_template=myTemplate, font_size=144)
#         self.add(tex)
# Out:
# [01/15/22 16:24:39] INFO     Writing "{$\mathscr{H} \rightarrow        ]8;id=37649;file:///usr/lib/python3.10/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=705958;file:///usr/lib/python3.10/site-packages/manim/utils/tex_file_writing.py#85\85]8;;\
#                              \mathbb{H}$}" to
#                              media/Tex/0a91069370a98f55.tex
#                     INFO                                             ]8;id=944378;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=435308;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py#729\729]8;;\
#                              File ready at '/home/samuel/Programmes/
#                              Notebooks/media/images/Notebooks/AddPac
#                              kageLatex_ManimCE_v0.14.0.png'
#                     INFO     Rendered AddPackageLatex                            ]8;id=434662;file:///usr/lib/python3.10/site-packages/manim/scene/scene.py\scene.py]8;;\:]8;id=793948;file:///usr/lib/python3.10/site-packages/manim/scene/scene.py#237\237]8;;\
#                              Played 0 animations

# %%
# %%manim LaTeXMathFonts
# class LaTeXMathFonts(Scene):
#     def construct(self):
#         tex = Tex(r'$\partial_t\omega + u\partial_x\omega + v\partial_y\omega = \nu \triangle \omega$', tex_template=TexFontTemplates.french_cursive, font_size=100)
#         self.add(tex)
# Out:
# [01/15/22 16:27:28] INFO                                             ]8;id=512518;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=323336;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py#729\729]8;;\
#                              File ready at '/home/samuel/Programmes/
#                              Notebooks/media/images/Notebooks/LaTeXM
#                              athFonts_ManimCE_v0.14.0.png'
#                     INFO     Rendered LaTeXMathFonts                             ]8;id=33945;file:///usr/lib/python3.10/site-packages/manim/scene/scene.py\scene.py]8;;\:]8;id=454405;file:///usr/lib/python3.10/site-packages/manim/scene/scene.py#237\237]8;;\
#                              Played 0 animations

# %%
# %%manim FollowingGraphCamera
# class FollowingGraphCamera(MovingCameraScene):
#     def construct(self):
#         self.camera.frame.save_state()
#
#         # create the axes and the curve
#         ax = Axes(x_range=[-1, 10], y_range=[-1, 10])
#         graph = ax.plot(np.cos, color=BLUE, x_range=[0, 3 * PI])
#
#         # create dots based on the graph
#         moving_dot = Dot(ax.i2gp(graph.t_min, graph), color=ORANGE)
#         dot_1 = Dot(ax.i2gp(graph.t_min, graph))
#         dot_2 = Dot(ax.i2gp(graph.t_max, graph))
#
#         self.add(ax, graph, dot_1, dot_2, moving_dot)
#         self.play(self.camera.frame.animate.scale(0.5).move_to(moving_dot))
#
#         def update_curve(mob):
#             mob.move_to(moving_dot.get_center())
#
#         self.camera.frame.add_updater(update_curve)
#         self.play(MoveAlongPath(moving_dot, graph, rate_func=linear))
#         self.camera.frame.remove_updater(update_curve)
#
#         self.play(Restore(self.camera.frame))
# Out:
# [01/15/22 16:38:24] INFO     Animation 0 : Partial movie file        ]8;id=772225;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=207201;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py#514\514]8;;\
#                              written in '/home/samuel/Programmes/Not
#                              ebooks/media/videos/Notebooks/1080p60/p
#                              artial_movie_files/FollowingGraphCamera
#                              /3815056640_4055257513_3532353004.mp4'
# [01/15/22 16:38:27] INFO     Animation 1 : Partial movie file        ]8;id=654003;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=790689;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py#514\514]8;;\
#                              written in '/home/samuel/Programmes/Not
#                              ebooks/media/videos/Notebooks/1080p60/p
#                              artial_movie_files/FollowingGraphCamera
#                              /3376365335_1457212660_2197462628.mp4'
# [01/15/22 16:38:28] INFO     Animation 2 : Partial movie file        ]8;id=261820;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=928118;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py#514\514]8;;\
#                              written in '/home/samuel/Programmes/Not
#                              ebooks/media/videos/Notebooks/1080p60/p
#                              artial_movie_files/FollowingGraphCamera
#                              /2999606411_3266477438_829930196.mp4'
#                     INFO     Combining to Movie file.                ]8;id=2448;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=921422;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py#608\608]8;;\
#                     INFO                                             ]8;id=666283;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=40467;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py#729\729]8;;\
#                              File ready at '/home/samuel/Programmes/
#                              Notebooks/media/videos/Notebooks/1080p6
#                              0/FollowingGraphCamera.mp4'
#                     INFO     Rendered FollowingGraphCamera                       ]8;id=922289;file:///usr/lib/python3.10/site-packages/manim/scene/scene.py\scene.py]8;;\:]8;id=865578;file:///usr/lib/python3.10/site-packages/manim/scene/scene.py#237\237]8;;\
#                              Played 3 animations
# <video src="media/jupyter/FollowingGraphCamera@2022-01-15@16-38-28.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim OpeningManim
# class OpeningManim(Scene):
#     def construct(self):
#         title = Tex(r"This is some \LaTeX")
#         basel = MathTex(r"\sum_{n=1}^\infty \frac{1}{n^2} = \frac{\pi^2}{6}")
#         VGroup(title, basel).arrange(DOWN)
#         self.play(
#             Write(title),
#             FadeIn(basel, shift=DOWN),
#         )
#         self.wait()
#
#         transform_title = Tex("That was a transform")
#         transform_title.to_corner(UP + LEFT)
#         self.play(
#             Transform(title, transform_title),
#             LaggedStart(*[FadeOut(obj, shift=DOWN) for obj in basel]),
#         )
#         self.wait()
#
#         grid = NumberPlane()
#         grid_title = Tex("This is a grid", font_size=72)
#         grid_title.move_to(transform_title)
#
#         self.add(grid, grid_title)  # Make sure title is on top of grid
#         self.play(
#             FadeOut(title),
#             FadeIn(grid_title, shift=UP),
#             Create(grid, run_time=3, lag_ratio=0.1),
#         )
#         self.wait()
#
#         grid_transform_title = Tex(
#             r"That was a non-linear function \\ applied to the grid"
#         )
#         grid_transform_title.move_to(grid_title, UL)
#         grid.prepare_for_nonlinear_transform()
#         self.play(
#             grid.animate.apply_function(
#                 lambda p: p
#                           + np.array(
#                     [
#                         np.sin(p[1]),
#                         np.sin(p[0]),
#                         0,
#                     ]
#                 )
#             ),
#             run_time=3,
#         )
#         self.wait()
#         self.play(Transform(grid_title, grid_transform_title))
#         self.wait()
# Out:
# [01/15/22 16:35:14] INFO     Writing "This is some \LaTeX" to          ]8;id=699074;file:///usr/lib/python3.10/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=486147;file:///usr/lib/python3.10/site-packages/manim/utils/tex_file_writing.py#85\85]8;;\
#                              media/Tex/c9129f64b4d15f4b.tex
# [01/15/22 16:35:15] INFO     Writing "\sum_{n=1}^\infty \frac{1}{n^2}  ]8;id=545622;file:///usr/lib/python3.10/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=759544;file:///usr/lib/python3.10/site-packages/manim/utils/tex_file_writing.py#85\85]8;;\
#                              = \frac{\pi^2}{6}" to
#                              media/Tex/f2839629d51d5776.tex
# [01/15/22 16:35:18] INFO     Animation 0 : Partial movie file        ]8;id=124064;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=348527;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py#514\514]8;;\
#                              written in '/home/samuel/Programmes/Not
#                              ebooks/media/videos/Notebooks/1080p60/p
#                              artial_movie_files/OpeningManim/4509745
#                              05_1335498644_4059817433.mp4'
# [01/15/22 16:35:19] INFO     Animation 1 : Partial movie file        ]8;id=91066;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=168531;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py#514\514]8;;\
#                              written in '/home/samuel/Programmes/Not
#                              ebooks/media/videos/Notebooks/1080p60/p
#                              artial_movie_files/OpeningManim/3478618
#                              6_398514950_3383504790.mp4'
#                     INFO     Writing "That was a transform" to         ]8;id=29799;file:///usr/lib/python3.10/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=528386;file:///usr/lib/python3.10/site-packages/manim/utils/tex_file_writing.py#85\85]8;;\
#                              media/Tex/75c8a091708666c1.tex
# [01/15/22 16:35:21] INFO     Animation 2 : Partial movie file        ]8;id=584531;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=9491;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py#514\514]8;;\
#                              written in '/home/samuel/Programmes/Not
#                              ebooks/media/videos/Notebooks/1080p60/p
#                              artial_movie_files/OpeningManim/3478618
#                              6_4070645906_279517403.mp4'
# [01/15/22 16:35:22] INFO     Animation 3 : Partial movie file        ]8;id=879052;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=899515;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py#514\514]8;;\
#                              written in '/home/samuel/Programmes/Not
#                              ebooks/media/videos/Notebooks/1080p60/p
#                              artial_movie_files/OpeningManim/3478618
#                              6_398514950_1181594316.mp4'
#                     INFO     Writing "This is a grid" to               ]8;id=462734;file:///usr/lib/python3.10/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=448508;file:///usr/lib/python3.10/site-packages/manim/utils/tex_file_writing.py#85\85]8;;\
#                              media/Tex/f94d6db8f758e87f.tex
# [01/15/22 16:35:27] INFO     Animation 4 : Partial movie file        ]8;id=307334;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=963720;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py#514\514]8;;\
#                              written in '/home/samuel/Programmes/Not
#                              ebooks/media/videos/Notebooks/1080p60/p
#                              artial_movie_files/OpeningManim/3478618
#                              6_3690750289_1766131787.mp4'
# [01/15/22 16:35:28] INFO     Animation 5 : Partial movie file        ]8;id=350718;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=121128;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py#514\514]8;;\
#                              written in '/home/samuel/Programmes/Not
#                              ebooks/media/videos/Notebooks/1080p60/p
#                              artial_movie_files/OpeningManim/3478618
#                              6_398514950_3006483632.mp4'
#                     INFO     Writing "That was a non-linear function   ]8;id=129067;file:///usr/lib/python3.10/site-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=1347;file:///usr/lib/python3.10/site-packages/manim/utils/tex_file_writing.py#85\85]8;;\
#                              \\ applied to the grid" to
#                              media/Tex/44a2f50ecf728444.tex
# [01/15/22 16:35:36] INFO     Animation 6 : Partial movie file        ]8;id=210928;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=188106;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py#514\514]8;;\
#                              written in '/home/samuel/Programmes/Not
#                              ebooks/media/videos/Notebooks/1080p60/p
#                              artial_movie_files/OpeningManim/3478618
#                              6_1563932938_3298323744.mp4'
# [01/15/22 16:35:37] INFO     Animation 7 : Partial movie file        ]8;id=567059;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=28130;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py#514\514]8;;\
#                              written in '/home/samuel/Programmes/Not
#                              ebooks/media/videos/Notebooks/1080p60/p
#                              artial_movie_files/OpeningManim/3478618
#                              6_398514950_1929079365.mp4'
# [01/15/22 16:35:39] INFO     Animation 8 : Partial movie file        ]8;id=433842;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=845924;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py#514\514]8;;\
#                              written in '/home/samuel/Programmes/Not
#                              ebooks/media/videos/Notebooks/1080p60/p
#                              artial_movie_files/OpeningManim/3478618
#                              6_3280074953_48133805.mp4'
# [01/15/22 16:35:41] INFO     Animation 9 : Partial movie file        ]8;id=296575;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=945396;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py#514\514]8;;\
#                              written in '/home/samuel/Programmes/Not
#                              ebooks/media/videos/Notebooks/1080p60/p
#                              artial_movie_files/OpeningManim/3478618
#                              6_398514950_4026884170.mp4'
#                     INFO     Combining to Movie file.                ]8;id=952615;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=443874;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py#608\608]8;;\
#                     INFO                                             ]8;id=10735;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=703867;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py#729\729]8;;\
#                              File ready at '/home/samuel/Programmes/
#                              Notebooks/media/videos/Notebooks/1080p6
#                              0/OpeningManim.mp4'
#                     INFO     Rendered OpeningManim                               ]8;id=426419;file:///usr/lib/python3.10/site-packages/manim/scene/scene.py\scene.py]8;;\:]8;id=822620;file:///usr/lib/python3.10/site-packages/manim/scene/scene.py#237\237]8;;\
#                              Played 10 animations
# <video src="media/jupyter/OpeningManim@2022-01-15@16-35-41.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim ContinuousMotion
# class ContinuousMotion(Scene):
#     def construct(self):
#         func = lambda pos: np.sin(pos[0] / 2) * UR + np.cos(pos[1] / 2) * LEFT
#         stream_lines = StreamLines(func, stroke_width=3, max_anchors_per_line=30)
#         self.add(stream_lines)
#         stream_lines.start_animation(warm_up=False, flow_speed=1.5)
#         self.wait(stream_lines.virtual_time / stream_lines.flow_speed)
# Out:
# [01/15/22 16:48:14] INFO     Animation 0 : Partial movie file        ]8;id=327310;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=334350;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py#514\514]8;;\
#                              written in '/home/samuel/Programmes/Not
#                              ebooks/media/videos/Notebooks/1080p60/p
#                              artial_movie_files/ContinuousMotion/450
#                              974505_1777792299_3918167152.mp4'
#                     INFO     Combining to Movie file.                ]8;id=556994;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=735431;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py#608\608]8;;\
# [01/15/22 16:48:15] INFO                                             ]8;id=594859;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=419111;file:///usr/lib/python3.10/site-packages/manim/scene/scene_file_writer.py#729\729]8;;\
#                              File ready at '/home/samuel/Programmes/
#                              Notebooks/media/videos/Notebooks/1080p6
#                              0/ContinuousMotion.mp4'
#                     INFO     Rendered ContinuousMotion                           ]8;id=593785;file:///usr/lib/python3.10/site-packages/manim/scene/scene.py\scene.py]8;;\:]8;id=329200;file:///usr/lib/python3.10/site-packages/manim/scene/scene.py#237\237]8;;\
#                              Played 1 animations
# <video src="media/jupyter/ContinuousMotion@2022-01-15@16-48-15.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>
